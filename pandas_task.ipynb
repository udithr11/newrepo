# %%
import pandas as pd

# %%
df=pd.read_csv('AgentPerformance.csv')

# %%
df1=pd.read_csv('AgentLogingReport.csv')

# %%
#1   Find out there avarage rating on weekly basis keep this in mind that they take two days of leave

# %%
df['converted_date']=pd.to_datetime(df['Date'])

# %%
df['week']=df['converted_date'].dt.weekofyear
# Out:
# /var/folders/8w/t31qdv4j4dq2wvj9jtrv8nsm0000gn/T/ipykernel_837/2646569843.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week']=df['converted_date'].dt.weekofyear

# %%
df6=df.drop(df[df['Total Chats']==0].index)  #dropping all the rows with 'total chats'=0
#as 0 Total chat implies no quiries taken on that day

# %%
df6.groupby(['Agent Name','week'])['Average Rating'].mean() 
#some people have total chats taken for the month =0 and their name won't be displayed 
#as i have deleted all the rows with 0 total chats. what to do? is there any other way?
# Out:
# Agent Name     week
# Aditya Shinde  26      3.850
#                27      4.516
#                28      4.746
# Aditya_iot     27      4.315
#                28      4.100
#                        ...
# Wasim          30      4.298
# Zeeshan        27      4.575
#                28      4.128
#                29      4.452
#                30      4.140
# Name: Average Rating, Length: 182, dtype: float64

# %%
#2      total working ways of each agent by counting the repetition agent name in df6

# %%
df6.groupby('Agent Name')['Agent Name'].count()
# Out:
# Agent Name
# Aditya Shinde             12
# Aditya_iot                17
# Ameya Jain                15
# Anirudh                    7
# Ankitjha                   3
# Anurag Tiwari              2
# Aravind                   14
# Ashad Nasim                2
# Ayushi Mishra             24
# Bharath                   19
# Boktiar Ahmed Bappy       26
# Chaitra K Hiremath         6
# Deepranjan Gupta          21
# Dibyanshu                  1
# Harikrishnan Shaji        19
# Hitesh Choudhary           1
# Hrisikesh Neogi           21
# Ishawant Kumar            24
# Jawala Prakash            25
# Jayant Kumar               8
# Jaydeep Dixit             21
# Khushboo Priya            26
# Madhulika G               24
# Mahak                      1
# Mahesh Sarade             18
# Maitry                    20
# Maneesh                    3
# Manjunatha A              25
# Mithun S                  18
# Mukesh                     2
# Mukesh Rao                 3
# ...

# %%
#3   total queries taken by adding up the total chat column

# %%
df.groupby('Agent Name')['Total Chats'].sum().reset_index()
# Out:
#        Agent Name  Total Chats
# 0       Abhishek             0
# 1         Aditya             0
# 2   Aditya Shinde          277
# 3     Aditya_iot           231
# 4         Amersh             0
# ..            ...          ...
# 65    Uday Mishra            0
# 66      Vasanth P            0
# 67         Vivek            44
# 68         Wasim           433
# 69       Zeeshan           542
#
# [70 rows x 2 columns]

# %%
#4     total feedback received

# %%
df.groupby('Agent Name')['Total Feedback'].sum().reset_index()
# Out:
#        Agent Name  Total Feedback
# 0       Abhishek                0
# 1         Aditya                0
# 2   Aditya Shinde             153
# 3     Aditya_iot              131
# 4         Amersh                0
# ..            ...             ...
# 65    Uday Mishra               0
# 66      Vasanth P               0
# 67         Vivek               20
# 68         Wasim              284
# 69       Zeeshan              335
#
# [70 rows x 2 columns]

# %%
df6
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2101   2102   7/1/2022       Jaydeep Dixit           25               0:01:15
# 2102   2103   7/1/2022  Shivananda Sonwane           23               0:01:24
# 2103   2104   7/1/2022      Khushboo Priya           24               0:01:46
# 2104   2105   7/1/2022     Hrisikesh Neogi           15               0:01:05
# 2105   2106   7/1/2022              Tarun            22               0:00:00
#
# ...

# %%
#5      avg rating between 3.5 to 4

# %%
df10=df6.groupby(['Agent Name'])['Average Rating'].mean().reset_index()

# %%
df10[(df10['Average Rating']>3.5) & (df10['Average Rating']<4)].head().reset_index()
# Out:
#    index Agent Name  Average Rating
# 0     28   Mithun S        3.931667
# 1     44   Shivan K        3.874545

# %%
#6    Agent name who have rating less then 3.5

# %%
df10[(df10['Average Rating']<3.5)].reset_index()
# Out:
#     index        Agent Name  Average Rating
# 0       3          Anirudh         2.764286
# 1       4         Ankitjha         2.666667
# 2       5     Anurag Tiwari        2.750000
# 3       7       Ashad Nasim        2.500000
# 4      13        Dibyanshu         0.000000
# 5      15  Hitesh Choudhary        0.000000
# 6      23            Mahak         3.000000
# 7      26          Maneesh         1.666667
# 8      30       Mukesh Rao         2.556667
# 9      39          Samprit         0.000000
# 10     52            Tarun         1.500000
# 11     53            Vivek         3.004000

# %%
#7,8     agent name who have rating more then 4.5  and how many feedback agents have received more then 4.5 average

# %%
df10[(df10['Average Rating']>4.5)].reset_index()
# Out:
#    index          Agent Name  Average Rating
# 0      0       Aditya Shinde        4.500833
# 1      6            Aravind         4.674286
# 2      9            Bharath         4.711053
# 3     20       Jaydeep Dixit        4.524286
# 4     29             Mukesh         4.645000
# 5     38     Saikumarreddy N        4.570000
# 6     46  Shivananda Sonwane        4.535000
# 7     47      Shubham Sharma        4.607619
# 8     49     Sudhanshu Kumar        5.000000
# 9     50       Suraj S Bilgi        4.680000

# %%
#9,10       average weekly response time and resolution time for each agent

# %%
df['seconds_response']=pd.to_timedelta(df['Average Response Time'])

# %%
df['total seconds response']=list(map(lambda x:x.total_seconds(),df['seconds_response']))

# %%
df['seconds_resolution']=pd.to_timedelta(df['Average Resolution Time'])

# %%
df['total seconds resolution']=list(map(lambda x:x.total_seconds(),df['seconds_resolution']))

# %%
#df=df.drop('total seconds resolution',axis=1)

# %%
df.groupby(['Agent Name','week'])['total seconds response'].mean().reset_index()
# Out:
#     Agent Name  week  total seconds response
# 0    Abhishek     26                0.000000
# 1    Abhishek     27                0.000000
# 2    Abhishek     28                0.000000
# 3    Abhishek     29                0.000000
# 4    Abhishek     30                0.000000
# ..         ...   ...                     ...
# 345   Zeeshan     26                0.000000
# 346   Zeeshan     27               23.571429
# 347   Zeeshan     28              123.428571
# 348   Zeeshan     29               62.857143
# 349   Zeeshan     30               63.833333
#
# [350 rows x 3 columns]

# %%
df.groupby(['Agent Name','week'])['total seconds resolution'].mean().reset_index()
# Out:
#     Agent Name  week  total seconds resolution
# 0    Abhishek     26                  0.000000
# 1    Abhishek     27                  0.000000
# 2    Abhishek     28                  0.000000
# 3    Abhishek     29                  0.000000
# 4    Abhishek     30                  0.000000
# ..         ...   ...                       ...
# 345   Zeeshan     26                  0.000000
# 346   Zeeshan     27                323.000000
# 347   Zeeshan     28                984.285714
# 348   Zeeshan     29                794.285714
# 349   Zeeshan     30                773.500000
#
# [350 rows x 3 columns]

# %%
#11    list of all agent names

# %%
set(df['Agent Name'])
# Out:
# {'Abhishek ',
#  'Aditya ',
#  'Aditya Shinde',
#  'Aditya_iot ',
#  'Amersh ',
#  'Ameya Jain',
#  'Anirudh ',
#  'Ankit Sharma',
#  'Ankitjha ',
#  'Anurag Tiwari',
#  'Aravind ',
#  'Ashad Nasim',
#  'Ashish ',
#  'Ayushi Mishra',
#  'Bharath ',
#  'Boktiar Ahmed Bappy',
#  'Chaitra K Hiremath',
#  'Deepranjan Gupta',
#  'Dibyanshu ',
#  'Harikrishnan Shaji',
#  'Hitesh Choudhary',
#  'Hrisikesh Neogi',
#  'Hyder Abbas',
#  'Ineuron Intelligence ',
#  'Ishawant Kumar',
#  'Jawala Prakash',
#  'Jayant Kumar',
#  'Jaydeep Dixit',
#  'Khushboo Priya',
#  'Madhulika G',
#  'Mahak ',
#  'Mahesh Sarade',
#  'Maitry ',
#  'Maneesh ',
#  'Manjunatha A',
#  'Mithun S',
#  'Mukesh ',
#  'Mukesh Rao ',
#  'Muskan Garg',
#  'Nandani Gupta',
#  'Nishtha Jain',
#  'Nitin M',
#  'Prabir Kumar Satapathy',
#  'Prateek _iot ',
#  'Prerna Singh',
#  'Rishav Dash',
#  'Rohan ',
#  'Saif Khan',
#  'Saikumarreddy N',
#  'Samprit ',
#  'Sandipan Saha',
#  'Sanjeev Kumar',
#  'Sanjeevan ',
# ...

# %%
#12    percentage of chat on which they have received a feedback

# %%
df['percentage_feedback']=(df['Total Feedback']/df['Total Chats'])*100

# %%
df.groupby('Agent Name')['percentage_feedback'].mean().reset_index()
# Out:
#        Agent Name  percentage_feedback
# 0       Abhishek                   NaN
# 1         Aditya                   NaN
# 2   Aditya Shinde            58.067722
# 3     Aditya_iot             60.188561
# 4         Amersh                   NaN
# ..            ...                  ...
# 65    Uday Mishra                  NaN
# 66      Vasanth P                  NaN
# 67         Vivek             47.666667
# 68         Wasim             66.449262
# 69       Zeeshan             65.002151
#
# [70 rows x 2 columns]

# %%
#13   Total contributation hour for each and every agents weekly basis

# %%
df1['duration_in_hr']=pd.to_timedelta(df1['Duration'])

# %%
df1['total_duration_in_hr']=list(map(lambda x:x.total_seconds(),df1['duration_in_hr']))

# %%
df1['total_duration_in_hr']=(df1['total_duration_in_hr'])/(60*60)

# %%
df1['week']=pd.to_datetime(df1['Date']).dt.weekofyear
# Out:
# /var/folders/8w/t31qdv4j4dq2wvj9jtrv8nsm0000gn/T/ipykernel_837/4061093491.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df1['week']=pd.to_datetime(df1['Date']).dt.weekofyear

# %%
df1.groupby(['Agent','week'])['total_duration_in_hr'].sum().reset_index()
# Out:
#             Agent  week  total_duration_in_hr
# 0   Aditya Shinde    30              0.036111
# 1      Aditya_iot    29              6.095278
# 2      Aditya_iot    30              9.635833
# 3          Amersh    30              3.063889
# 4      Ameya Jain    29             24.083056
# ..            ...   ...                   ...
# 84          Tarun    26            514.138889
# 85          Wasim    29             19.625556
# 86          Wasim    30             28.553611
# 87        Zeeshan    29             24.427500
# 88        Zeeshan    30             24.661111
#
# [89 rows x 3 columns]

# %%
#14   totalpercentage of active hour for a month

# %%
df1['month']=pd.to_datetime(df1['Date']).dt.month

# %%
df11=df1.groupby(['Agent','month'])['total_duration_in_hr'].sum().reset_index()

# %%
df11['percentage_of_active_hr_for_a_month']=((df11['total_duration_in_hr'])/(11*24))*100
#the given table AgentLogingReport.csv is only from 21st to 30th july. so total hours in 11 days=11*24
#to find the percentage of active hour for the given time= (total_duration_in_hr/(11*24))*100

# %%
df11
# Out:
#                      Agent  month  total_duration_in_hr  \
# 0            Aditya Shinde      7              0.036111
# 1               Aditya_iot      7             15.731111
# 2                   Amersh      7              3.063889
# 3               Ameya Jain      7             42.075556
# 4                 Ankitjha      7              2.266944
# 5            Anurag Tiwari      7              2.778889
# 6                  Aravind      7             24.299167
# 7            Ayushi Mishra      7             38.121667
# 8                  Bharath      7             48.076667
# 9      Boktiar Ahmed Bappy      7             40.268611
# 10      Chaitra K Hiremath      7             34.325556
# 11        Deepranjan Gupta      7            106.275278
# 12               Dibyanshu      7             52.595833
# 13      Harikrishnan Shaji      7             53.714722
# 14         Hrisikesh Neogi      7             57.568611
# 15             Hyder Abbas      7              0.388056
# ...
